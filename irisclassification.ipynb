# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani-202/Machine-Learning/blob/main/irisclassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
import pydotplus
from IPython.display import Image
from io import StringIO as stringIO

iris = load_iris()
X = iris.data
y = iris.target

tree_clf = DecisionTreeClassifier(max_depth=3)
tree_clf.fit(X, y)

# Visualize the tree

dot_data = stringIO()
from sklearn.tree import export_graphviz
export_graphviz(
    tree_clf,
    out_file=dot_data,
    feature_names=iris.feature_names,
    class_names=iris.target_names,
    rounded=True,
    filled=True
)


graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
image = graph.create_png()

Image(image)
